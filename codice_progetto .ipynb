# %%
import pandas as pd

#stampare i dati
pd.read_excel("file_di_dati.xlsx", sheet_name="porzioni di viaggio") 
pd.read_excel("file_di_dati.xlsx", sheet_name="tempi di percorrenza a vuoto") 

#salvare i dati dentro una variabile
xlsx1 = pd.read_excel("file_di_dati.xlsx", sheet_name="porzioni di viaggio") 
xlsx2 = pd.read_excel("file_di_dati.xlsx", sheet_name="tempi di percorrenza a vuoto") 

#filtrare e salvare solo alcune colonne dentro una variabile
#in questo caso verranno selezionate la colonna A e le colonne dalla C alla E
T_i = pd.read_excel("file_di_dati.xlsx",'porzioni di viaggio', usecols='E')
T_f = pd.read_excel("file_di_dati.xlsx",'porzioni di viaggio', usecols='F')

#xlsx1 #(levo l'hashtag se voglio vedere gli elementi nella variabile)
#xlsx2 #(levo l'hashtag se voglio vedere gli elementi nella variabile)
#T_i #(levo l'hashtag se voglio vedere gli elementi nella variabile)
#T_f #(levo l'hashtag se voglio vedere gli elementi nella variabile)
# Out:
#               Unnamed: 5
# 0             final time
# 1    2020-11-27 07:21:00
# 2    2020-11-27 07:35:00
# 3    2020-11-27 07:38:00
# 4    2020-11-27 07:58:00
# ..                   ...
# 153  2020-11-28 18:05:00
# 154  2020-11-28 17:50:00
# 155  2020-11-28 18:20:00
# 156  2020-11-28 18:50:00
# 157                  NaN
#
# [158 rows x 1 columns]
